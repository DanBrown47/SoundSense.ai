# %%
# !pip install essentia-tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting essentia-tensorflow
#   Downloading essentia_tensorflow-2.1b6.dev1034-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (291.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.4/291.4 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from essentia-tensorflow) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from essentia-tensorflow) (1.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from essentia-tensorflow) (6.0)
# Installing collected packages: essentia-tensorflow
# Successfully installed essentia-tensorflow-2.1b6.dev1034

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/ICT Project/weights_metadata_openl3.json" "weights_metadata_openl3.json"
# !cp "/content/drive/MyDrive/ICT Project/extract_openl3_embeddings.py" "extract_openl3_embeddings.py"
# !cp "/content/drive/MyDrive/ICT Project/openL3.zip" "openL3.zip"
# !cp "/content/drive/MyDrive/ICT Project/songs.zip" "songs.zip"
# !unzip "openL3.zip"
# !unzip "songs.zip"
# Out:
# Archive:  openL3.zip
#    creating: openL3/
#   inflating: openL3/tonal_atonal-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/danceability-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/danceability-openl3-music-mel128-emb512-1.json
#   inflating: openL3/mood_acoustic-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/mood_electronic-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/voice_instrumental-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/voice_instrumental-openl3-music-mel128-emb512-1.json
#   inflating: openL3/mood_electronic-openl3-music-mel128-emb512-1.json
#   inflating: openL3/gender-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/mood_acoustic-openl3-music-mel128-emb512-1.json
#   inflating: openL3/mood_aggressive-openl3-music-mel128-emb512-1.json
#   inflating: openL3/mood_party-openl3-music-mel128-emb512-1.json
#   inflating: openL3/gender-openl3-music-mel128-emb512-1.json
#   inflating: openL3/mood_party-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/mood_aggressive-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/mood_happy-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/mood_sad-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/mood_happy-openl3-music-mel128-emb512-1.json
#   inflating: openL3/mood_relaxed-openl3-music-mel128-emb512-1.pb
#   inflating: openL3/mood_sad-openl3-music-mel128-emb512-1.json
#   inflating: openL3/mood_relaxed-openl3-music-mel128-emb512-1.json
#   inflating: openL3/tonal_atonal-openl3-music-mel128-emb512-1.json
#   inflating: openL3/openl3-music-mel128-emb512-3.json
#   inflating: openL3/openl3-music-mel128-emb512-3.pb
# Archive:  songs.zip
#   inflating: 1, 2, 3 (feat Jason Derulo & De La Ghetto) - Sofia Reyes.m4a
#   inflating: Aaluma Doluma - Anirudh Ravichander, Badshah.m4a
#   inflating: Ae Ajnabi - Udit Narayan, Mahalakshmi Iyer.m4a
#   inflating: Aeternum - John Lunn, Eivør.m4a
#   inflating: Agar Tum Saath Ho - Alka Yagnik, Arijit Singh.m4a
#   inflating: Ale Ale - AR Rahman, Karthik, Chitra Sivaraman, Siddharth, Genelia D'Souza.m4a
#   inflating: Annul Maelae - Harris Jayaraj, Sudha Ragunathan.m4a
#   inflating: Apna Bana Le - Arijit Singh, Sachin-Jigar.m4a
#   inflating: Apocalypse - Cigarettes After Sex.m4a
#   inflating: Arabic Kuthu - Halamithi Habibo - Anirudh Ravichander, Jonita Gandhi.m4a
#   inflating: Armatopia - Johnny Marr.m4a
#   inflating: Battle Cry - Imagine Dragons.m4a
#   inflating: Battle Symphony - Linkin Park.m4a
#   inflating: Believer - Imagine Dragons.m4a
#   inflating: Black Water Lilies - Aurora.m4a
#   inflating: Blank - Disfigure.m4a
#   inflating: Blue Jeans (Remastered 2011) - Lana Del Rey.m4a
#   inflating: Bones - Imagine Dragons.m4a
#   inflating: Born To Die - Lana Del Rey.m4a
#   inflating: Can We Kiss Forever (Instrumental) - Kinà.m4a
#   inflating: Can We Kiss Forever - Kinà.m4a
#   inflating: Chahun Main Ya Naa - Palak Muchhal, Arijit Singh.m4a
#   inflating: Chaiyya Chaiyya - Sukhwinder Singh, Sapna Awasthi.m4a
#   inflating: Chammak Challo - Vishal & Shekhar, Akon.m4a
#   inflating: Chinna Chinna Asai - Minmini.m4a
#   inflating: Chittiyaan Kalaiyaan - Meet Bros.m4a
#   inflating: Chop Shop - Tyler Bates, Joel J Richard.m4a
#   inflating: Cold - Neffex.m4a
#   inflating: cotton candy - Iris.m4a
#   inflating: creature - Iris.m4a
#   inflating: Crystallize - Lindsey Stirling.m4a
#   inflating: Darkside - Alan Walker, AuRa, Tomine Harket.m4a
#   inflating: Desi Kalakaar - Yo Yo Honey Singh.m4a
#   inflating: Despacito - Luis Fonsi, Daddy Yankee.m4a
#   inflating: Destiny Is All - John Lunn, Eivør.m4a
#   inflating: Diamond Heart - Sophia Somajo, Alan Walker.m4a
#   inflating: Dilliwaali Girlfriend - Pritam, Arijit Singh, Sunidhi Chauhan.m4a
#   inflating: Dil Se Re - AR Rahman, Anuradha, Anupama.m4a
#   inflating: Dippam Dappam - Anirudh Ravichander, Anthony Daasan.m4a
#   inflating: Don't Let Me Go - Cigarettes After Sex.m4a
#   inflating: Dura - Daddy Yankee.m4a
#   inflating: Elangathu solo - Sriram Parthasarathy.m4a
#   inflating: Ennavale Adi Ennavale - P Unnikrishnan.m4a
#   inflating: En Sarwame - Nobin Paul, Ananya.m4a
#   inflating: Etho Sayana - Sachin Warrier.m4a
#   inflating: Faded - Alan Walker.m4a
#   inflating: from inside a car - Iris.m4a
#   inflating: Fuego Lento - Drake Bell.m4a
#   inflating: Gaandakannazhagi - Anirudh Ravichander, Neeti Mohan.m4a
#   inflating: Galvanize (Edit) - The Chemical Brothers.m4a
#   inflating: Gasolina - Daddy Yankee.m4a
#   inflating: Gerua - Pritam, Arijit Singh, Antara Mitra.m4a
#   inflating: giving in - Iris.m4a
#   inflating: Goodbye - Apparat.m4a
#   inflating: Goodbye Brother - Ramin Djawadi.m4a
#   inflating: Guzarish - Javed Ali.m4a
#   inflating: Half The World Away - Aurora.m4a
#   inflating: Hamari Adhuri Kahani - Arijit Singh.m4a
#   inflating: hanging around youcrackers - Iris.m4a
#   inflating: Harleys In Hawaii - Katy Perry.m4a
#   inflating: Heavenly - Cigarettes After Sex.m4a
#   inflating: Helig - John Lunn, Eivør.m4a
#   inflating: hidden springs - Iris.m4a
#   inflating: Hosanna - Vijay Prakash, Suzanne D'Mello, AR Rahman, Blaaze.m4a
#   inflating: Humdard - Mithoon, Arijit Singh.m4a
#   inflating: Hum Mar Jayenge - Tulsi Kumar, Arijit Singh.m4a
#   inflating: Hum Naa Rahein Hum - Mithoon, Benny Dayal.m4a
#   inflating: Ichu Ichu - Vijay Antony, Sangeetha Rajeshwaran.m4a
#   inflating: I Don't Do Personals - Ramin Djawadi.m4a
#   inflating: Ignite - Alan Walker, Julie Bergan, K-391.m4a
#   inflating: Industry - Mire Kay.m4a
#   inflating: In My Mind - M86, Susie Q.m4a
#   inflating: Innum Konjam Naeram - Shweta Mohan, Vijay Prakash, AR Rahman.m4a
#   inflating: In The End (Mellen Gi Remix) - Tommee Profitt, Fleurie, Mellen Gi.m4a
#   inflating: Invisible - Julius Dreisig & Zeus X Crona.m4a
#   inflating: İzmir Marşı - Coldrex.m4a
#   inflating: Jeevamshamayi - Duet - KS Harisankar, Shreya Ghoshal.m4a
#   inflating: Jingunamani - Ranjith, Sunidhi Chauhan, D Imman.m4a
#   inflating: Jiya Jale - Lata Mangeshkar, MG Sreekumar.m4a
#   inflating: Kabhi Alvida Naa Kehna - Shankar-Ehsaan-Loy, Sonu Nigam, Alka Yagnik.m4a
#   inflating: Kalasala Kalasala - Thaman S, L R Eswari, T Rajendar, Solar Sai.m4a
#   inflating: Kal Ho Naa Ho - Shankar-Ehsaan-Loy, Sonu Nigam.m4a
#   inflating: K - Cigarettes After Sex.m4a
#   inflating: Kesariya - Pritam, Arijit Singh, Amitabh Bhattacharya.m4a
#   inflating: Koi Tumsa Nahin - Sonu Nigam, Shreya Ghoshal.m4a
#   inflating: La Calin (CallmeArco Remix) - Serhat Durmus.m4a
#   inflating: Let Her Go - Passenger.m4a
#   inflating: Lívstræðrir - John Lunn, Eivør.m4a
#   inflating: Love Me Like You Do - Ellie Goulding.m4a
#   inflating: Lungi Dance - Yo Yo Honey Singh.m4a
#   inflating: Magenta Riddim - DJ Snake.m4a
#   inflating: Main Tera Boyfriend - Arijit Singh, Neha Kakkar.m4a
#   inflating: Malai Mangum Neram (Female Unplugged) - Deepthi Balasubramanian, Aakash Srinivasan.m4a
#   inflating: Malai Mangum Neram - Prakash Nikki.m4a
#   inflating: Manasellam Mazhaiye - Sonu Nigam, Saindhavi, GV Prakash Kumar.m4a
#   inflating: Marana Mass - Anirudh Ravichander, S P Balasubrahmanyam.m4a
#   inflating: Masakali Lofi - Aelo.m4a
#   inflating: Mayaanadhi - Shahabaz Aman.m4a
#   inflating: MAYDAY - TheFatRat.m4a
#   inflating: Mehabooba - Ananya Bhat.m4a
#   inflating: Mehabooba - Ravi Basrur, Ananya Bhat.m4a
#   inflating: Memories - JFla.m4a
#   inflating: Mental Manadhil - AR Rahman, Jonita Gandhi.m4a
#   inflating: Mere Haath Mein - Sunidhi Chauhan, Sonu Nigam, Jatin-Lalit, Prasoon Joshi.m4a
#   inflating: Meri Aashiqui - Palak Muchhal, Arijit Singh.m4a
#   inflating: Minunundae Mullapolae - Ashwin Renju, Karthik, Manu Manjith, Tovino Thomas, Balu Varghese, Santhy Balachandran, Neha Iyer.m4a
#   inflating: Mizhiyil - Shahabaz Aman.m4a
#   inflating: Mohabbat Barsa De - Arko, Arjun, Arijit Singh, Samira Koppikar.m4a
#   inflating: Mounam Chorum Neram - Rinu Razak, Shaan Rahman.m4a
#   inflating: Mundhinam - Prashanthini, Harris Jayaraj, Naresh Iyer.m4a
#   inflating: Muskurane (Romantic) - Jeet Gannguli, Arijit Singh.m4a
#   inflating: My England - John Lunn, Eivør.m4a
#   inflating: Naatu Naatu - Rahul Sipligunj, Kaala Bhairava, M M Keeravani.m4a
#   inflating: Nainowale Ne - Neeti Mohan.m4a
#   inflating: Nanavare - Tessa Chavara, Vipin Lal, Lal.m4a
#   inflating: Nee Himamazhayayi - Kailas Menon, K S Hari Shankar, Nithya Mammen.m4a
#   inflating: Neeyen Vennila - Haricharan, Chinmayi Sripada.m4a
#   inflating: Nenjae Yezhu - AR Rahman.m4a
#   inflating: Nenjodu Cherthu - Sreejith - Saachin, Aalaap Raju.m4a
#   inflating: Nervous - The Neighbourhood.m4a
#   inflating: Nothing's Gonna Hurt You Baby - Cigarettes After Sex.m4a
#   inflating: No Time for Caution - Hans Zimmer.m4a
#   inflating: Ollulleru - Praseetha Chalakudy.m4a
#   inflating: One Two Three Four (Get On The Dance Floor) - Vishal & Shekhar, Vishal Dadlani, Hamsika Iyer, Sricharan Kasturirangan.m4a
#   inflating: Only Time - Enya.m4a
#   inflating: On My Mind - Ellie Goulding.m4a
#   inflating: On My Way - Alan Walker, Sabrina Carpenter, Farruko.m4a
#   inflating: Oru Dinam - Anand Bhaskar.m4a
#   inflating: Oru Vakkum Mindathe - Vineeth Sreenivasan.m4a
#   inflating: Oru Vakkum (Version 1) - Alphons Jospeh, Mridula Warrier.m4a
#   inflating: Pakka Local - Geetha Madhuri, Sagar.m4a
#   inflating: Param Sundari - AR Rahman, Shreya Ghoshal.m4a
#   inflating: Phir Mohabbat - Mohammed Irfan, Arijit Singh, Saim Bhat.m4a
#   inflating: Pistah - Rajesh Murugesan, Shabareesh Varma.m4a
#   inflating: Poovukkul - AR Rahman, Sujatha Mohan, P Unnikrishnan.m4a
#   inflating: Pudhu Vellai Mazhai - Unni Menon, Sujatha Mohan.m4a
#   inflating: Pullikkuyile - Sujatha Mohan.m4a
#   inflating: Puthiyoru Lokam - Hesham Abdul Wahab, Vimal Roy, Bhadra Rajin.m4a
#   inflating: Puthumazhayai (Shreya Ghoshal) - Shreya Ghoshal, Gopi Sunder.m4a
#   inflating: Pyaar Ki Ek Kahani - Sonu Nigam, Shreya Ghoshal.m4a
#   inflating: Radioactive - Imagine Dragons.m4a
#   inflating: Ready Steady Go (Korean Style) - Paul Oakenfold.m4a
#   inflating: repose - Iris.m4a
#   inflating: Ringa Ringa - Devi Sri Prasad, Priya Hemesh.m4a
#   inflating: Roar - Katy Perry.m4a
#   inflating: Runaway - Aurora.m4a
#   inflating: Runaway - Laura Brehm, Nikonn.m4a
#   inflating: Running With The Wolves - Aurora.m4a
#   inflating: Sadda Dil Vi Tu (Ga Ga Ga Ganpati) - Sachin-Jigar, Hard Kaur.m4a
#   inflating: Samjhawan - Jawad Ahmad, Toshi Sabri, Arijit Singh, Shreya Ghoshal.m4a
#   inflating: Sanam Re - Arijit Singh, Mithoon.m4a
#   inflating: Sapna Jahan - Ajay-Atul, Sonu Nigam, Neeti Mohan.m4a
#   inflating: Sawan Aaya Hai - Tony Kakkar, Mithoon, Arijit Singh.m4a
#   inflating: Sceptic Heart - Black Red Gold.m4a
#   inflating: Senthoora - D Imman, Luksimi Sivaneswaralingam.m4a
#   inflating: Sil Sil Sil Sillala - P Unnikrishnan, Sujatha Mohan.m4a
#   inflating: Sing Me to Sleep - Alan Walker.m4a
#   inflating: Skyfall - Adele.m4a
#   inflating: Sky High - Elektronomia.m4a
#   inflating: Sonapareeya - Javed Ali, Nakash Aziz, AR Rahman, Haricharan.m4a
#   inflating: Space Song (Beach House Cover) - Alles Club.m4a
#   inflating: Still DRE (Instrumental) - Dr Dre.m4a
#   inflating: Subha Hone Na De - Mika Singh, Shefali Alvares.m4a
#   inflating: Taal Se Taal - Alka Yagnik, Udit Narayan.m4a
#   inflating: Take Me To Church - Hozier.m4a
#   inflating: Tere Bina - AR Rahman, Chinmayi Sripada, Murtuza Khan, Qadir Khan.m4a
#   inflating: The Rains of Castamere - Ramin Djawadi, Serj Tankian.m4a
#   inflating: These Are My Feelings - MrFIRA.m4a
#   inflating: The Spectre - Alan Walker.m4a
#   inflating: Think - Kaleida.m4a
#   inflating: Thumbi Penne - Gopi Sunder, Siddharth Menon.m4a
#   inflating: Thunder - Imagine Dragons.m4a
#   inflating: Time - Hans Zimmer.m4a
#   inflating: Titli - Vishal & Shekhar, Chinmayi Sripada, Gopi Sunder.m4a
#   inflating: Trust Each Other - Ramin Djawadi.m4a
#   inflating: Tumhi Dekho Naa - Shankar-Ehsaan-Loy, Sonu Nigam, Alka Yagnik.m4a
#   inflating: Tum Hi Ho - Arijit Singh.m4a
#   inflating: Tum Tum - Aishwarya Kumar, Darshana Menon, Reena Gilbert, Vidhya Gopal, Yashika Sikka, Thaman S.m4a
#   inflating: Tum Tum - Satya Yamini, Tejaswini, Srivardhini, Aditi Bhavaraju, Roshini JKV, Thaman S.m4a
#   inflating: Unakkul Naane - Rohini, Harris Jayaraj, Pritt, Dilushselva.m4a
#   inflating: Unn Perai Sollum - GV Prakash Kumar, Naresh Iyer, Shreya Ghoshal, Haricharan.m4a
#   inflating: Uska Hi Banana - Arijit Singh.m4a
#   inflating: Usure Pogudhey - AR Rahman, Karthik.m4a
#   inflating: Uyiril Thodum - Sooraj Santhosh, Anne Amie.m4a
#   inflating: Vaathi Coming - Anirudh Ravichander, Gana Balachandar.m4a
#   inflating: Vertigo (Spitfya Remix) - Rob Gasser & Laura Brehm.m4a
#   inflating: Vibin' Out - FKJ, ((( O ))).m4a
#   inflating: Warrior - Aurora.m4a
#   inflating: Welcome to the Fire - Willyecho.m4a
#   inflating: Yaarindha Devadhai, Pt 1 - Hariharan.m4a
#   inflating: Yaar Intha - Haricharan, Yuvan Shankar Raja.m4a
#   inflating: your mind, the universe - Iris.m4a
#   inflating: Zaroorat - Mithoon, Mustafa Zahid.m4a

# %% [markdown]
# # OpenL3 models

# %%
import essentia
import json
import essentia.standard as es
from essentia import Pool
from essentia.standard import MonoLoader, TensorflowPredictMusiCNN, TensorflowPredict2D

import numpy as np
import pandas as pd
import os

pd.options.display.max_columns = 100

# %% [markdown]
# Code from Essentia docs

# %%
from pathlib import Path
import essentia.standard as es
import numpy as np
from essentia import Pool

class MelSpectrogramOpenL3:
    def __init__(self, hop_time):
        self.hop_time = hop_time

        self.sr = 48000
        self.n_mels = 128
        self.frame_size = 2048
        self.hop_size = 242
        self.a_min = 1e-10
        self.d_range = 80
        self.db_ref = 1.0

        self.patch_samples = int(1 * self.sr)
        self.hop_samples = int(self.hop_time * self.sr)

        self.w = es.Windowing(
            size=self.frame_size,
            normalized=False,
        )
        self.s = es.Spectrum(size=self.frame_size)
        self.mb = es.MelBands(
            highFrequencyBound=self.sr / 2,
            inputSize=self.frame_size // 2 + 1,
            log=False,
            lowFrequencyBound=0,
            normalize="unit_tri",
            numberBands=self.n_mels,
            sampleRate=self.sr,
            type="magnitude",
            warpingFormula="slaneyMel",
            weighting="linear",
        )

    def compute(self, audio_file):
        audio = es.MonoLoader(filename=audio_file, sampleRate=self.sr)()

        batch = []
        for audio_chunk in es.FrameGenerator(
            audio, frameSize=self.patch_samples, hopSize=self.hop_samples
        ):
            melbands = np.array(
                [
                    self.mb(self.s(self.w(frame)))
                    for frame in es.FrameGenerator(
                        audio_chunk,
                        frameSize=self.frame_size,
                        hopSize=self.hop_size,
                        validFrameThresholdRatio=0.5,
                    )
                ]
            )

            melbands = 10.0 * np.log10(np.maximum(self.a_min, melbands))
            melbands -= 10.0 * np.log10(np.maximum(self.a_min, self.db_ref))
            melbands = np.maximum(melbands, melbands.max() - self.d_range)
            melbands -= np.max(melbands)

            batch.append(melbands.copy())
        return np.vstack(batch)


class EmbeddingsOpenL3:
    def __init__(self, graph_path, hop_time=1, batch_size=60, melbands=128):
        self.hop_time = hop_time
        self.batch_size = batch_size

        self.graph_path = Path(graph_path)

        self.x_size = 199
        self.y_size = melbands
        self.squeeze = False

        self.permutation = [0, 3, 2, 1]

        self.input_layer = "melspectrogram"
        self.output_layer = "embeddings"

        self.mel_extractor = MelSpectrogramOpenL3(hop_time=self.hop_time)

        self.model = es.TensorflowPredict(
            graphFilename=str(self.graph_path),
            inputs=[self.input_layer],
            outputs=[self.output_layer],
            squeeze=self.squeeze,
        )

    def compute(self, audio_file):
        mel_spectrogram = self.mel_extractor.compute(audio_file)
        # in OpenL3 the hop size is computed in the feature extraction level

        hop_size_samples = self.x_size

        batch = self.__melspectrogram_to_batch(mel_spectrogram, hop_size_samples)

        pool = Pool()
        embeddings = []
        nbatches = int(np.ceil(batch.shape[0] / self.batch_size))
        for i in range(nbatches):
            start = i * self.batch_size
            end = min(batch.shape[0], (i + 1) * self.batch_size)
            pool.set(self.input_layer, batch[start:end])
            out_pool = self.model(pool)
            embeddings.append(out_pool[self.output_layer].squeeze())

        return np.vstack(embeddings)

    def __melspectrogram_to_batch(self, melspectrogram, hop_time):
        npatches = int(np.ceil((melspectrogram.shape[0] - self.x_size) / hop_time) + 1)
        batch = np.zeros([npatches, self.x_size, self.y_size], dtype="float32")
        for i in range(npatches):
            last_frame = min(i * hop_time + self.x_size, melspectrogram.shape[0])
            first_frame = i * hop_time
            data_size = last_frame - first_frame

            # the last patch may be empty, remove it and exit the loop
            if data_size <= 0:
                batch = np.delete(batch, i, axis=0)
                break
            else:
                batch[i, :data_size] = melspectrogram[first_frame:last_frame]

        batch = np.expand_dims(batch, 1)
        batch = es.TensorTranspose(permutation=self.permutation)(batch)
        return batch

# %%
files = os.listdir()
audio_file_list = [f for f in files if os.path.isfile(f) and f.endswith(".m4a")]

with open('weights_metadata_openl3.json') as json_file:
    model_weights_metadata = json.load(json_file)
path = "openL3/"
song_path = ''
embedding_model_weights = "openL3/openl3-music-mel128-emb512-3.pb"

# %%
flag = True
column_labels = ['song name']
rows = []

for song in audio_file_list:
    extractor = EmbeddingsOpenL3(embedding_model_weights)
    embeddings = extractor.compute(song)

    classification_models = {}
    for key in model_weights_metadata:
        value = model_weights_metadata[key]

        weight_file = path + value + ".pb"
        mdata_file = path + value + ".json"

        metadata = json.load(open(mdata_file, 'r'))
        input = metadata['schema']['inputs'][0]['name']
        output = metadata['schema']['outputs'][0]['name']
        classes = metadata['classes']

        model = TensorflowPredict2D(graphFilename=weight_file, output=output, input=input)
        
        classification_models[key] = [model, classes]
    
    song_name = ".".join(song.split('.')[:-1])
    scores = [song_name]

    for key in classification_models:
        value = classification_models[key]
        predictions = np.mean(value[0](embeddings), axis=0)

        if flag:
            for i in range(0, len(predictions)):
                label = str(key) + "_" + str(value[1][i])
                column_labels.append(label)
    
        for i in range(0, len(predictions)):
            scores.append(predictions[i])

    flag = False
    rows.append(scores)

# %%
df = pd.DataFrame(rows, columns=column_labels)
df
# Out:
#                                              song name  \
# 0    Kesariya - Pritam, Arijit Singh, Amitabh Bhatt...
# 1    Tumhi Dekho Naa - Shankar-Ehsaan-Loy, Sonu Nig...
# 2          Yaar Intha - Haricharan, Yuvan Shankar Raja
# 3                                 Masakali Lofi - Aelo
# 4       Mounam Chorum Neram - Rinu Razak, Shaan Rahman
# ..                                                 ...
# 188        Blue Jeans (Remastered 2011) - Lana Del Rey
# 189  Naatu Naatu - Rahul Sipligunj, Kaala Bhairava,...
# 190                      Radioactive - Imagine Dragons
# 191  Gaandakannazhagi - Anirudh Ravichander, Neeti ...
# 192  Nothing's Gonna Hurt You Baby - Cigarettes Aft...
#
#      danceability_danceable  danceability_not_danceable  \
# 0                  0.327049                    0.672951
# 1                  0.158344                    0.841655
# 2                  0.501876                    0.498124
# 3                  0.274075                    0.725925
# 4                  0.222101                    0.777899
# ..                      ...                         ...
# 188                0.190522                    0.809478
# 189                0.550202                    0.449798
# 190                0.292800                    0.707200
# 191                0.427049                    0.572950
# 192                0.105491                    0.894509
#
#      mood_acoustic_acoustic  mood_acoustic_non_acoustic  \
# 0                  0.366784                    0.633216
# 1                  0.569611                    0.430389
# 2                  0.459691                    0.540309
# 3                  0.611383                    0.388617
# 4                  0.639006                    0.360994
# ..                      ...                         ...
# 188                0.192048                    0.807952
# 189                0.066733                    0.933267
# 190                0.201368                    0.798633
# 191                0.218301                    0.781699
# 192                0.206500                    0.793500
#
#      mood_aggressive_aggressive  mood_aggressive_not_aggressive  \
# 0                      0.023151                        0.976849
# 1                      0.008512                        0.991488
# 2                      0.025964                        0.974036
# 3                      0.013785                        0.986215
# 4                      0.007554                        0.992445
# ..                          ...                             ...
# 188                    0.179450                        0.820550
# 189                    0.304841                        0.695159
# 190                    0.348434                        0.651566
# 191                    0.154261                        0.845739
# 192                    0.058049                        0.941951
#
#      mood_electronic_electronic  mood_electronic_non_electronic  \
# 0                      0.116046                        0.883954
# 1                      0.155452                        0.844548
# 2                      0.216236                        0.783763
# 3                      0.286667                        0.713333
# 4                      0.112350                        0.887650
# ..                          ...                             ...
# 188                    0.107247                        0.892753
# 189                    0.517704                        0.482296
# 190                    0.195731                        0.804269
# 191                    0.191794                        0.808205
# 192                    0.203690                        0.796310
#
#      mood_happy_happy  mood_happy_non_happy  mood_party_non_party  \
# 0            0.272419              0.727581              0.658665
# 1            0.144596              0.855404              0.778762
# 2            0.284831              0.715168              0.606585
# 3            0.086680              0.913321              0.918501
# 4            0.147789              0.852211              0.822626
# ..                ...                   ...                   ...
# 188          0.224718              0.775282              0.565376
# 189          0.117790              0.882211              0.184868
# 190          0.165367              0.834633              0.562312
# 191          0.307215              0.692784              0.292882
# 192          0.023968              0.976032              0.855951
#
#      mood_party_party  mood_relaxed_non_relaxed  mood_relaxed_relaxed  \
# 0            0.341335                  0.118784              0.881216
# 1            0.221238                  0.025113              0.974887
# 2            0.393415                  0.123932              0.876068
# 3            0.081499                  0.017125              0.982875
# 4            0.177375                  0.027179              0.972821
# ..                ...                       ...                   ...
# 188          0.434625                  0.236674              0.763326
# 189          0.815132                  0.332171              0.667829
# 190          0.437688                  0.307172              0.692828
# 191          0.707118                  0.391425              0.608575
# 192          0.144049                  0.045887              0.954113
#
#      mood_sad_non_sad  mood_sad_sad  tonal_atonal_tonal  tonal_atonal_atonal  \
# 0            0.186672      0.813327            0.812663             0.187337
# 1            0.095975      0.904025            0.655382             0.344618
# 2            0.333369      0.666631            0.772035             0.227965
# 3            0.142679      0.857321            0.820264             0.179736
# 4            0.094230      0.905770            0.708135             0.291865
# ..                ...           ...                 ...                  ...
# 188          0.380252      0.619748            0.918202             0.081798
# 189          0.620437      0.379563            0.836728             0.163272
# 190          0.500451      0.499549            0.832805             0.167195
# 191          0.521874      0.478126            0.838267             0.161733
# 192          0.146288      0.853712            0.845362             0.154638
#
#      voice_gender_female  voice_gender_male  voice_instrumental_instrumental  \
# 0               0.385912           0.614088                         0.142868
# 1               0.371912           0.628088                         0.224780
# 2               0.372645           0.627354                         0.235784
# 3               0.594566           0.405434                         0.199318
# 4               0.384298           0.615702                         0.148614
# ..                   ...                ...                              ...
# 188             0.373277           0.626724                         0.086718
# 189             0.304262           0.695737                         0.420082
# 190             0.310269           0.689731                         0.186443
# 191             0.245630           0.754369                         0.157606
# 192             0.350160           0.649840                         0.354170
#
#      voice_instrumental_voice
# 0                    0.857132
# 1                    0.775220
# 2                    0.764216
# 3                    0.800682
# 4                    0.851386
# ..                        ...
# 188                  0.913281
# 189                  0.579918
# 190                  0.813557
# 191                  0.842394
# 192                  0.645830
#
# [193 rows x 23 columns]

# %%
original_labels = df.columns
columns_to_drop = ['danceability_not_danceable', 'mood_acoustic_non_acoustic', 'mood_aggressive_not_aggressive', 'mood_electronic_non_electronic', 'mood_happy_non_happy', 'mood_party_non_party', 'mood_relaxed_non_relaxed', 'mood_sad_non_sad',  'tonal_atonal_atonal']
rename_labels = {'danceability_danceable':'danceability', 'mood_acoustic_acoustic':'mood_acoustic', 'mood_aggressive_aggressive':'mood_aggressive', 'mood_electronic_electronic':'mood_electronic', 
                 'mood_happy_happy':'mood_happy', 'mood_party_party':'mood_party', 'mood_relaxed_relaxed':'mood_relaxed', 'mood_sad_sad':'mood_sad', 
                 'voice_instrumental_instrumental':'instrumental', 'voice_instrumental_voice':'voice', 'voice_gender_female':'voice_female', 'voice_gender_male':'voice_male',
                 'tonal_atonal_tonal':'tonal'
                 }

# %%
df.drop(columns=columns_to_drop, inplace=True)
df.rename(columns=rename_labels, inplace=True)

# %%
df
# Out:
#                                              song name  danceability  \
# 0    Kesariya - Pritam, Arijit Singh, Amitabh Bhatt...      0.327049
# 1    Tumhi Dekho Naa - Shankar-Ehsaan-Loy, Sonu Nig...      0.158344
# 2          Yaar Intha - Haricharan, Yuvan Shankar Raja      0.501876
# 3                                 Masakali Lofi - Aelo      0.274075
# 4       Mounam Chorum Neram - Rinu Razak, Shaan Rahman      0.222101
# ..                                                 ...           ...
# 188        Blue Jeans (Remastered 2011) - Lana Del Rey      0.190522
# 189  Naatu Naatu - Rahul Sipligunj, Kaala Bhairava,...      0.550202
# 190                      Radioactive - Imagine Dragons      0.292800
# 191  Gaandakannazhagi - Anirudh Ravichander, Neeti ...      0.427049
# 192  Nothing's Gonna Hurt You Baby - Cigarettes Aft...      0.105491
#
#      mood_acoustic  mood_aggressive  mood_electronic  mood_happy  mood_party  \
# 0         0.366784         0.023151         0.116046    0.272419    0.341335
# 1         0.569611         0.008512         0.155452    0.144596    0.221238
# 2         0.459691         0.025964         0.216236    0.284831    0.393415
# 3         0.611383         0.013785         0.286667    0.086680    0.081499
# 4         0.639006         0.007554         0.112350    0.147789    0.177375
# ..             ...              ...              ...         ...         ...
# 188       0.192048         0.179450         0.107247    0.224718    0.434625
# 189       0.066733         0.304841         0.517704    0.117790    0.815132
# 190       0.201368         0.348434         0.195731    0.165367    0.437688
# 191       0.218301         0.154261         0.191794    0.307215    0.707118
# 192       0.206500         0.058049         0.203690    0.023968    0.144049
#
#      mood_relaxed  mood_sad     tonal  voice_female  voice_male  instrumental  \
# 0        0.881216  0.813327  0.812663      0.385912    0.614088      0.142868
# 1        0.974887  0.904025  0.655382      0.371912    0.628088      0.224780
# 2        0.876068  0.666631  0.772035      0.372645    0.627354      0.235784
# 3        0.982875  0.857321  0.820264      0.594566    0.405434      0.199318
# 4        0.972821  0.905770  0.708135      0.384298    0.615702      0.148614
# ..            ...       ...       ...           ...         ...           ...
# 188      0.763326  0.619748  0.918202      0.373277    0.626724      0.086718
# 189      0.667829  0.379563  0.836728      0.304262    0.695737      0.420082
# 190      0.692828  0.499549  0.832805      0.310269    0.689731      0.186443
# 191      0.608575  0.478126  0.838267      0.245630    0.754369      0.157606
# 192      0.954113  0.853712  0.845362      0.350160    0.649840      0.354170
#
#         voice
# 0    0.857132
# 1    0.775220
# 2    0.764216
# 3    0.800682
# 4    0.851386
# ..        ...
# 188  0.913281
# 189  0.579918
# 190  0.813557
# 191  0.842394
# 192  0.645830
#
# [193 rows x 14 columns]

# %%
df.to_csv('song_dataset_openl3.csv', index=False)
